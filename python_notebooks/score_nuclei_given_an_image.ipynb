# %% [markdown]
# # Scoring nuclei
#
# Here we use the models that we have built to segment nuclei, extract nuclear morphology and chromatin organization features and finally reduce dimensionality to obtain a MGS score that reflect cell health. (Healthy nuclei will have higher values).
#
#
# To demonstrate our work we have provided a few sample images here (from the test dataset) and one can run the script below to segment nuclei, extract  their chromatin features and obtain their Mechano-Genomic Score or cell heath index. For each image in this dataset we visualise this by coloring the cetroid of each nucleus based on their score. For reference, we include the DNA labelled image and the protein expression of standard biomarkers such as HER2, ER and PR.

# %%
# import libraries
import sys
sys.path.append("..")
import os
from src.utlis.score_cells import score_vis_with_groundtruth_data

# set up the paths 
path_to_data = os.path.join(os.path.dirname(os.getcwd()),'example_data/image_with_ground_truth')
DNA_labeled_regions = os.path.join(path_to_data,'DNA/')
biomarker_labeled_regions = os.path.join(path_to_data,'HER_ER_PR/')

# score nuclei 

score_vis_with_groundtruth_data(DNA_labeled_regions,biomarker_labeled_regions)
# Out:
# Segmenting images.....
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.507725, nms_thresh=0.3.
# ...
# 100%|██████████| 16/16 [00:00<00:00, 22.54it/s]
# Computing nuclear and chromatin features....
# ...
#   0%|          | 0/384 [00:00<?, ?it/s]
# Computing cell heath score (MGS)....
# /media/pathy_s/54fe7289-2a61-4f3a-ac84-eeea3c0d1d2f/temp/breast_cancer_tumorigenesis_score/example_data/image_with_ground_truth/scoring_model/score_nuclei.R
#   0%|          | 0/4 [00:00<?, ?it/s]
